# %%
import requests

# %%
# 1 - mapeando informacao
headers = {
    'X-GitHub-Api-Version': '2022-11-28'
}

# %%
base_api = 'https://api.github.com'

# %%
user = 'OneBitCodeBlog'

# %%
url = f'{base_api}/users/{user}/repos'

# %%
print(url)
# Out:
# https://api.github.com/users/OneBitCodeBlog/repos

# %%
# 2 - realizando a requisicao
response = requests.get(url, headers=headers)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(len(response.json()))
# Out:
# 30

# %%
print(response.json())
# Out:
# [{'id': 261289433, 'node_id': 'MDEwOlJlcG9zaXRvcnkyNjEyODk0MzM=', 'name': 'aulao_de_react', 'full_name': 'OneBitCodeBlog/aulao_de_react', 'private': False, 'owner': {'login': 'OneBitCodeBlog', 'id': 34001998, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM0MDAxOTk4', 'avatar_url': 'https://avatars.githubusercontent.com/u/34001998?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/OneBitCodeBlog', 'html_url': 'https://github.com/OneBitCodeBlog', 'followers_url': 'https://api.github.com/users/OneBitCodeBlog/followers', 'following_url': 'https://api.github.com/users/OneBitCodeBlog/following{/other_user}', 'gists_url': 'https://api.github.com/users/OneBitCodeBlog/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/OneBitCodeBlog/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/OneBitCodeBlog/subscriptions', 'organizations_url': 'https://api.github.com/users/OneBitCodeBlog/orgs', 'repos_url': 'https://api.github.com/users/OneBitCodeBlog/repos', 'events_url': 'https://api.github.com/users/OneBitCodeBlog/events{/privacy}', 'received_events_url': 'https://api.github.com/users/OneBitCodeBlog/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/OneBitCodeBlog/aulao_de_react', 'description': 'Exemplos usados no aulão de React', 'fork': False, 'url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react', 'forks_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/forks', 'keys_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/teams', 'hooks_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/hooks', 'issue_events_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/issues/events{/number}', 'events_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/events', 'assignees_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/assignees{/user}', 'branches_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/branches{/branch}', 'tags_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/tags', 'blobs_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/languages', 'stargazers_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/stargazers', 'contributors_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/contributors', 'subscribers_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/subscribers', 'subscription_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/subscription', 'commits_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/contents/{+path}', 'compare_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/merges', 'archive_url': 'https://api.github.com/repos/OneBitCodeBlog/aulao_de_react/{archive_format}{/ref}',  ...
